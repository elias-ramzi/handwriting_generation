# %% [markdown]
# # Results

# %%
import sys
sys.path.insert(0, '..')
from utils import plot_stroke

# %% [markdown]
# This is what you should modify:

# %%
from models.dummy import generate_unconditionally, generate_conditionally, recognize_stroke

# %% [markdown]
# Please, don't modify anything below.
#
# ### Unconditional generation:

# %%
stroke = generate_unconditionally()
plot_stroke(stroke)
# Out:
# Creating a series of strokes:   1%|          | 5/437 [00:00<00:09, 46.40it/s]
# Generating a random sentence of  437 strokes
# Creating a series of strokes: 100%|██████████| 437/437 [00:12<00:00, 36.20it/s]

# %% [markdown]
# ### Conditional generation:

# %%
stroke = generate_conditionally(text='welcome to lyrebird')
plot_stroke(stroke)

# %% [markdown]
# ### Handwriting recognition:

# %%
text = recognize_stroke(stroke)
print(text)
# Out:
# welcome to lyrebird
